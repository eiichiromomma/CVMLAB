# %% [markdown]
# # 共役を使った計算
# SymPyでは```conjugate```が共役。

# %%
from sympy import I, symbols, solve, Abs, arg, expand_complex, pi, conjugate, sqrt
R1, R2, R3, X1, X2 = symbols('R_1 R_2 R_3 X_1 X_2', real=True)
V = symbols(r'\dot{V}')
Z1 = R1+I*X1
Z2 = R2-I*X2
Z3 = R3
I1 = V/Z1
display(I1)
display(expand_complex(I1))
display(I1.subs([(R1,10),(R2,5),(R3,20),(X1,5),(X2,10),(V,(10+10*I)/sqrt(2))]).evalf())
I2 = V/Z2
display(I2)
display(expand_complex(I2))
display(I2.subs([(R1,10),(R2,5),(R3,20),(X1,5),(X2,10),(V,(10+10*I)/sqrt(2))]).evalf())
I3 = V/Z3
display(I3)
display(I3.subs([(R1,10),(R2,5),(R3,20),(X1,5),(X2,10),(V,(10+10*I)/sqrt(2))]).evalf())
# Out:
# \dot{V}/(R_1 + I*X_1)
# R_1*re(\dot{V})/(R_1**2 + X_1**2) + X_1*im(\dot{V})/(R_1**2 + X_1**2) + I*(R_1*im(\dot{V})/(R_1**2 + X_1**2) - X_1*re(\dot{V})/(R_1**2 + X_1**2))
# 0.848528137423857 + 0.282842712474619*I
# \dot{V}/(R_2 - I*X_2)
# R_2*re(\dot{V})/(R_2**2 + X_2**2) - X_2*im(\dot{V})/(R_2**2 + X_2**2) + I*(R_2*im(\dot{V})/(R_2**2 + X_2**2) + X_2*re(\dot{V})/(R_2**2 + X_2**2))
# -0.282842712474619 + 0.848528137423857*I
# \dot{V}/R_3
# 0.353553390593274 + 0.353553390593274*I

# %%
Yp = 1/Z1 + 1/Z2 + 1/Z3
display(Yp)
display(expand_complex(Yp))
display(Yp.subs([(R1,10),(R2,5),(R3,20),(X1,5),(X2,10),(V,(10+10*I)/sqrt(2))]).evalf())
Zp = 1/Yp
display(Zp)
display(Zp.subs([(R1,10),(R2,5),(R3,20),(X1,5),(X2,10),(V,(10+10*I)/sqrt(2))]).evalf())
# Out:
# 1/(R_2 - I*X_2) + 1/(R_1 + I*X_1) + 1/R_3
# R_1/(R_1**2 + X_1**2) + R_2/(R_2**2 + X_2**2) + I*(-X_1/(R_1**2 + X_1**2) + X_2/(R_2**2 + X_2**2)) + 1/R_3
# 0.17 + 0.04*I
# 1/(1/(R_2 - I*X_2) + 1/(R_1 + I*X_1) + 1/R_3)
# 5.57377049180328 - 1.31147540983607*I

# %%
P10=10*Abs(I1)**2
display(P10)
display(P10.subs([(R1,10),(R2,5),(R3,20),(X1,5),(X2,10),(V,(10+10*I)/sqrt(2))]).evalf())
P5 = 5*Abs(I2)**2
display(P5)
display(P5.subs([(R1,10),(R2,5),(R3,20),(X1,5),(X2,10),(V,(10+10*I)/sqrt(2))]).evalf())
P20 = 20*Abs(I3)**2
display(P20)
display(P20.subs([(R1,10),(R2,5),(R3,20),(X1,5),(X2,10),(V,(10+10*I)/sqrt(2))]).evalf())
# Out:
# 10*Abs(\dot{V})**2/(R_1**2 + X_1**2)
# 8.00000000000000
# 5*Abs(\dot{V})**2/(R_2**2 + X_2**2)
# 4.00000000000000
# 20*Abs(\dot{V}/R_3)**2
# 5.00000000000000

# %% [markdown]
# 複素電力を求める際に電圧の共役をとるため```V*conjugate(IT)```としている

# %%
IT=Yp*V
display(IT.subs([(R1,10),(R2,5),(R3,20),(X1,5),(X2,10),(V,(10+10*I)/sqrt(2))]).evalf())
S = V * conjugate(IT)
display(S)
display(S.subs([(R1,10),(R2,5),(R3,20),(X1,5),(X2,10),(V,(10+10*I)/sqrt(2))]).evalf())
# Out:
# 0.919238815542512 + 1.48492424049175*I
# \dot{V}*(1/(R_2 + I*X_2) + 1/(R_1 - I*X_1) + 1/R_3)*conjugate(\dot{V})
# 17.0 - 4.0*I
