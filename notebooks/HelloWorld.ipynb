# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ディレクトリの中身を表示

# %%
ls
# Out:
#  ドライブ C のボリューム ラベルがありません。
#  ボリューム シリアル番号は 1E60-0A4C です
#
#  C:\Users\CVMLAB のディレクトリ
#
# 2014/11/08  16:11    <DIR>          .
# 2014/11/08  16:11    <DIR>          ..
# 2014/11/08  16:11    <DIR>          .ipynb_checkpoints
# 2014/11/08  14:50    <DIR>          .ipython
# 2014/11/08  16:14    <DIR>          .matplotlib
# 2014/10/28  16:51    <DIR>          Contacts
# 2014/10/28  17:06    <DIR>          Desktop
# 2014/10/28  19:20    <DIR>          Documents
# 2014/11/08  14:58    <DIR>          Downloads
# 2014/10/28  16:51    <DIR>          Favorites
# 2014/11/08  16:34           314,349 HelloWorld.ipynb
# 2014/11/08  14:57            91,814 lena.jpg
# 2014/10/28  16:51    <DIR>          Links
# 2014/10/28  16:51    <DIR>          Music
# 2014/10/28  16:51    <DIR>          Pictures
# 2014/10/28  16:51    <DIR>          Saved Games
# 2014/10/28  16:51    <DIR>          Searches
# 2014/11/08  10:42    <DIR>          Videos
#                2 個のファイル             406,163 バイト
# ...

# %%
import cv2
img = cv2.imread('lena.jpg')
cv2.imshow('Lena',img)
cv2.waitKey(0)
# Out:
# 32

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %% [markdown]
# そのままだと青赤が入れ替わった画像が表示されてしまう。

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
# %pwd
# Out:
# u'C:\\Users\\CVMLAB'

# %% [markdown]
# * セルの種類をMarkdownにすると非常に便利
# * 箇条書きもこうなる
